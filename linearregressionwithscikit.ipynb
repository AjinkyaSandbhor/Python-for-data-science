# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import r2_score

# %%
from sklearn.datasets import make_regression

# %%
#generating data using make regression

data = make_regression(n_samples=1000, n_features=1, noise=20)

# %%
X = data[0]
y = data[1]

# %% [markdown]
# tuple ka 0 th index ka data x mein and 1 st index ka data 1st index mein divide kiyaa

# %%
df = pd.DataFrame(X, columns=["Feature1"])
df["Target"] = y

# %%
df.head()
# Out:
#    Feature1     Target
# 0  1.918010  36.538224
# 1 -0.585270 -13.842871
# 2  1.739215  69.068811
# 3  0.599620  30.379258
# 4 -1.082361 -52.124642

# %%
plt.title("Feature vs Target")
plt.scatter(df["Feature1"],df["Target"])
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=57)

# %%
X_train.shape
# Out:
# (750, 1)

# %%
y_train.shape
# Out:
# (750,)

# %%
X_test.shape
# Out:
# (250, 1)

# %%
y_test.shape
# Out:
# (250,)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.6654408087363062

# %%
model.coef_
# Out:
# array([25.34530934])

# %%
model.intercept_
# Out:
# 0.9857425748634566

# %%
# to calculate the r2 score - r squared score
# total sum of squared error (TSS)
# sum of squared residual (SSR)

# r2 = 1-(SSR/TSS)

# The range of r2 score is 0-1

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 t_mean = tips.mean()
#
# NameError: name 'tips' is not defined
